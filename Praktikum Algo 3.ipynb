# %%
"""
Nama : Salwa Nur Shafira
NIM : 065002500019
Tanggal : Kamis, 2 Oktober 2025
Tugas : Menentukan Jenis Segitiga
"""
# Program menentukan jenis segitiga

# Input panjang sisi
a = float(input("Masukkan sisi pertama: "))
b = float(input("Masukkan sisi kedua: "))
c = float(input("Masukkan sisi ketiga: "))

if a + b > c and a + c > b and b + c > a:
  if a == b == c:
    print("Segitiga sama sisi")
  elif a == b or a == c or b == c:
    print("Segitiga sama kaki")
  elif a*a + b*b == c*c or a*a + c*c == b*b or b*b + c*c == a*a:
    print("Segitiga siku-siku")
  else:
    print("Segitiga sembarang")
else:
  print("Bukan segitiga")
# Out:
# Masukkan sisi pertama: 3
# Masukkan sisi kedua: 4
# Masukkan sisi ketiga: 5
# Segitiga siku-siku

# %%
"""
Nama : Salwa Nur Shafira
NIM : 065002500019
Tanggal : Kamis, 2 Oktober 2025
Tugas : Modul 3 Latihan Kedua Program untuk pembayaran belanjaan
"""

print("Program Perhitungan Dsikon Pembelanjaan USAKTIF")

Nama = input("Masukkan Nama Anda: ")
NIM = input("Masukkan NIM Anda: ")
total_belanja = int(input("Masukkan Total Belanja: Rp "))

kupon = input("Masukkan kode kupon(jika tidak ada, tekan Enter): ")

if kupon == "IKL6309":
    print("Selamat, Anda mendapat diskon 100%")
    diskon = 1.0
else:
  if 40000 <= total_belanja <= 89999:
    diskon = 0.2
  elif 90000 <= total_belanja <= 189999:
    diskon = 0.4
  elif 190000 <= total_belanja <= 389999:
    diskon = 0.6
  elif total_belanja >= 390000:
    diskon = 0.8
  else:
    diskon = 0.0

potongan = total_belanja * diskon
total_bayar = total_belanja - potongan

print(f"Total belanja: Rp {total_belanja}")
print(f"Diskon: Rp {int(diskon*100)}%")
print(f"Potongan : Rp {int(potongan)}")
print(f"Total yang harus dibayar: Rp {int(total_bayar)}")
# Out:
# Program Perhitungan Dsikon Pembelanjaan USAKTIF
# Masukkan Nama Anda: Salwa Nur Shafira
# Masukkan NIM Anda: 065002500019
# Masukkan Total Belanja: Rp 220000
# Masukkan kode kupon(jika tidak ada, tekan Enter): IKL6309
# Selamat, Anda mendapat diskon 100%
# Total belanja: Rp 220000
# Diskon: Rp 100%
# Potongan : Rp 220000
# Total yang harus dibayar: Rp 0
