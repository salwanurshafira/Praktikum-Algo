# %%
"""
Nama : Salwa Nur Shafira
NIM : 065002500019
Tanggal : Kamis, 18 September 2025
Program untuk menampilkan data alamat
"""
print("Masukkan data kamu dengan sesuai!")
nama = input("Masukan nama kamu: ")
alamat = input("Alamat/tempat tinggal:")
nama_kampus = input("Masukkan nama kampus kamu:")
jurusan = input("Masukkan jurusan kamu:")
gedung = input("Masukkan gedung jurusan kamu:")

print("Berikut data kamu!")

print(f"Halo nama saya {nama}, saya tinggal di {alamat}, saya kuliah di {nama_kampus}, jurusan saya {jurusan}, digedung {gedung}, dan saya siap ikut praktikum algoritma!")
# Out:
# Masukkan data kamu dengan sesuai!
# Masukan nama kamu: salwa
# Alamat/tempat tinggal:Jalan Madrid Selatan 3 No. 5 Tangerang
# Masukkan nama kampus kamu:Trisakti
# Masukkan jurusan kamu:Sistem informasi
# Masukkan gedung jurusan kamu:E
# Berikut data kamu!
# Halo nama saya salwa, saya tinggal di Jalan Madrid Selatan 3 No. 5 Tangerang, saya kuliah di Trisakti, jurusan saya Sistem informasi, digedung E, dan saya siap ikut praktikum algoritma!

# %%
"""
Nama : Salwa Nur Shafira
NIM : 065002500019
Tanggal : Kamis, 18 September 2025
Tugas : Luas Ruangan
"""
print("Hitung Luas Ruangan")
pr =int(input("Masukan panjang ruangan:"))
lr = int(input("Masukan lebar ruangan:"))
rumus = pr * lr
print(f"Luas ruangan adalah {rumus} meter")
# Out:
# Hitung Luas Ruangan
# Masukan panjang ruangan:30
# Masukan lebar ruangan:20
# Luas ruangan adalah 600 meter

# %%
"""
Nama : Salwa Nur Shafira
NIM : 065002500019
Tanggal : Kamis, 18 September 2025
Tugas : Luas Ruangan
"""
print("Hitung Luas Ruangan")
pr =int(input("Masukan panjang ruangan:"))
lr = int(input("Masukan lebar ruangan:"))
rumus = pr * 39.37 * lr * 39.37
print(f"Luas ruangan adalah {rumus} inch")
# Out:
# Hitung Luas Ruangan
# Masukan panjang ruangan:30
# Masukan lebar ruangan:20
# Luas ruangan adalah 929998.1399999999 inch

# %%
"""
Nama : Salwa Nur Shafira
NIM : 065002500019
Tanggal : Kamis, 18 September 2025
Tugas : Menghitung Body Mass Index (BMI)
"""
print("Hitung Body Mass Index (BMI)")
nama = input("Masukan nama kamu:")
berat_badan = int(input("Masukan berat badan kamu:"))
tinggi_badan = int(input("Masukan tinggi badan kamu:"))
rumus = berat_badan / (tinggi_badan * tinggi_badan)
print(f"Body Mass Index adalah {rumus}")
# Out:
# Hitung Body Mass Index (BMI)
# Masukan nama kamu:salwa
# Masukan berat badan kamu:58
# Masukan tinggi badan kamu:155
# Body Mass Index adalah 0.002414151925078044
