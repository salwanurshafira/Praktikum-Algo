# %%
"""
Nama = Salwa Nur Shafira
NIM = 065002500019
Tanggal = Kamis, 20 November 2025
Tugas = fungsi perpangkatan menggunakan konsep rekursif (tanpa for/while)
"""

def jumlah_rekursif(n, total=0, index=1):
    if n == 0:
      return total

    angka = int(input(f"Masukkan angka ke-{index}: "))
    return jumlah_rekursif(n - 1, total + angka, index + 1)

jumlah = int(input("Masukkan Jumlah: "))
hasil = jumlah_rekursif(jumlah)

print(f"Hasil dai=ri penjumlahan adalah: {hasil}")
# Out:
# Masukkan Jumlah: 3
# Masukkan angka ke-1: 1
# Masukkan angka ke-2: 2
# Masukkan angka ke-3: 3
# Hasil dai=ri penjumlahan adalah: 6

# %%
"""
Nama = Salwa Nur Shafira
NIM = 065002500019
Tanggal = Kamis, 27 November 2025
Tugas = fungsi perpangkatan menggunakan konsep rekursif (tanpa for/while)
"""

def hitung_pangkat_positif(base, power):

    if power == 0:
        return 1

    if power == 1:
        return base

    else:
        return base * hitung_pangkat_positif(base, power - 1)

def pangkat_rekursif(base, power):

    if power >= 0:
        return hitung_pangkat_positif(base, power)
    else:

        pangkat_positif = hitung_pangkat_positif(base, -power)
        return 1 / pangkat_positif

print("Ini merupakan program pemangkatan negatif dan positif, tekan enter untuk berhenti")

while True:

    base_str = input("\nMasukkan Angka : ")
    if base_str == "":
        print("Program Selesai")
        break

    base = float(base_str)

    power_str = input("Masukkan Pangkatnya : ")
    if power_str == "":
        print("Program Selesai")
        break

    power = int(power_str)

    hasil = pangkat_rekursif(base, power)
    print(f"Hasilnya adalah: {hasil}")
# Out:
# Ini merupakan program pemangkatan negatif dan positif, tekan enter untuk berhenti
#
# Masukkan Angka : 2
# Masukkan Pangkatnya : 2
# Hasilnya adalah: 4.0
#
# Masukkan Angka :
# Program Selesai
